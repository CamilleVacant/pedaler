# %%
import pandas as pd

# %%
url = 'https://docs.google.com/spreadsheets/d/1ECBD-JE82j-V9TlhjYuf2L4fw6iEdOyjeewDXPYNE_c/pub?gid=0&single=true&output=csv'

# %%
df = pd.read_csv(url)

# %%
df.head()
# Out:
#    Ville Opérateur (type) Opérateur (nom) Vélo (type) Offre (type)  \
# 0  Paris           Public           Velib   Mécanique      Forfait
# 1  Paris           Public           Velib  Electrique      Forfait
# 2  Paris           Public           Velib   Mécanique      Forfait
# 3  Paris           Public           Velib  Electrique      Forfait
# 4  Paris           Public           Velib   Mécanique      Forfait
#
#   Offre (nom) Engagement (en mois)  Engagement (en jours)  \
# 0     V-libre                   12                    NaN
# 1     V-libre                   12                    NaN
# 2      V-plus                   12                    NaN
# 3      V-plus                   12                    NaN
# 4       V-max                   12                    NaN
#
#   Prix au déverrouillage Prix à la minute Prix pour 30 minutes Mensualité  \
# 0                      0              NaN                    1          0
# ...
